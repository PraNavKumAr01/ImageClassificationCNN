# %%
import tensorflow as tf
import os

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')

# %%
gpus
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %% [markdown]
# ### CLEANING UP THE IMAGES

# %%
# !pip3 install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.8.0.74-cp37-abi3-macosx_11_0_arm64.whl (33.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.1/33.1 MB 1.4 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: numpy>=1.21.2 in /Users/pranav/miniforge3/lib/python3.10/site-packages (from opencv-python) (1.25.2)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.8.0.74

# %%
import cv2
import imghdr

# %%
data_dir = 'data'

# %%
img_exts = ['jpeg','jpg','bmp','png']

# %%
for image_class in os.listdir(data_dir):
    class_dir = os.path.join(data_dir, image_class)
    if not os.path.isdir(class_dir):  # Check if it's a directory before proceeding
        continue
    for image in os.listdir(class_dir):
        img_path = os.path.join(class_dir, image)
        try:
            img = cv2.imread(img_path)
            tip = imghdr.what(img_path)
            if tip not in img_exts:
                print("Invalid image extension: {}".format(img_path))
                os.remove(img_path)
        except Exception as e:
            print("Issue with image: {}".format(img_path))
            os.remove(img_path)
# Out:
# Invalid image extension: data/sad/50740738-portrC3A4ts-der-traurige-menschen.jpg
# Invalid image extension: data/sad/44861512-smiling-man-in-a-crowd-of-sad-people.jpg
# Invalid image extension: data/sad/1800x1200_visual_guide_to_seasonal_affective_disorder_sad_slideshow.jpg
# Invalid image extension: data/sad/sad-people-chairs-group-therapy-session_23-2148752072.jpg
# Invalid image extension: data/sad/african-american-depressive-sad-broken-260nw-475790911.jpg
# Invalid image extension: data/sad/5cd731f92100002f007a7304.jpeg
# Invalid image extension: data/sad/depressed-man-studio-shot-260nw-404652526.jpg
# Invalid image extension: data/sad/sad-people-group-therapy-session_23-2148752071.jpg
# Invalid image extension: data/sad/14HRhniN7B7Fqx5GCoFpQ3A.jpeg
# Invalid image extension: data/sad/secret-signs-of-loneliness-01-1440x810.jpg
# Invalid image extension: data/sad/2560px-Sad-Mental-Illness.jpg
# Invalid image extension: data/sad/cry-360x240.gif

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
data = tf.keras.utils.image_dataset_from_directory('data')
# Out:
# Found 148 files belonging to 2 classes.
# 2023-08-07 23:29:49.151376: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2023-08-07 23:29:49.151417: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2023-08-07 23:29:49.151424: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2023-08-07 23:29:49.152236: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-08-07 23:29:49.152555: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
data_iterator = data.as_numpy_iterator()

# %%
batch = data_iterator.next()

# %%
len(batch)
# Out:
# 2

# %%
batch[0].shape
# Out:
# (32, 256, 256, 3)

# %%
fig, ax = plt.subplots(ncols = 4, figsize = (20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %%
# HAPPY - 0
# SAD - 1

# %% [markdown]
# ### PREPROCESS DATA

# %%
data = data.map(lambda x, y : (x/255, y))

# %%
scaled = data.as_numpy_iterator().next()

# %%
scaled[0].min()
# Out:
# 0.0

# %%
scaled[0].max()
# Out:
# 1.0

# %%
fig, ax = plt.subplots(ncols = 4, figsize = (20,20))
for idx, img in enumerate(scaled[0][:4]):
    ax[idx].imshow(img)
    ax[idx].title.set_text(scaled[1][idx])

# %%
len(data)
# Out:
# 5

# %%
train_size = int(len(data)*.7)
val_size = int(len(data)*.2)
test_size = int(len(data)*.1)+1

# %%
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)

# %% [markdown]
# ### FUN PART

# %% [markdown]
# #### DEEP LEARING MODEL

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# %%
model = Sequential()

# %%
model.add(Conv2D(16, (3,3), 1, activation = 'relu', input_shape = (256,256,3)))
model.add(MaxPooling2D())
model.add(Conv2D(32, (3,3), 1, activation = 'relu'))
model.add(MaxPooling2D())
model.add(Conv2D(16, (3,3), 1, activation = 'relu'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(256, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))

# %%
optimizer = tf.keras.optimizers.legacy.Adam()

# %%
model.compile(optimizer = optimizer,loss = tf.losses.BinaryCrossentropy(), metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 127, 127, 16)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 62, 62, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 16)        4624
#
#  max_pooling2d_2 (MaxPoolin  (None, 30, 30, 16)        0
#  g2D)
#
#  flatten (Flatten)           (None, 14400)             0
#
#  dense (Dense)               (None, 256)               3686656
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 3696625 (14.10 MB)
# Trainable params: 3696625 (14.10 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### TRAINING

# %%
logdir = 'logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir = logdir)

# %%
hist = model.fit(train, epochs = 20, validation_data = val, callbacks = [tensorboard_callback])
